# %%
import pandas as pd
import json

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
d
# Out:
# {'packetType': 'D',
#  'data': {'checkEngineLightFlag': 'F',
#   'batteryVoltageStableTime': 0,
#   'batteryVoltageStable': '0',
#   'batteryVoltageOff': '12.42',
#   'batteryCrankParamTN': '-0.08',
#   'batteryCrankParamVN': '0.00',
#   'batteryCrankParamTP': '-0.08',
#   'batteryCrankParamVP': '0.00',
#   'batteryCrankParamTT': '-0.00008',
#   'batteryCrankParamV0': '0.00',
#   'batteryVoltageMaxOn': '13.05',
#   'batteryVoltageMinOn': '12.97',
#   'batteryVoltageMaxOff': '12.46',
#   'batteryVoltageMinOff': '12.36',
#   'batteryVoltageOnAverage': '13.02',
#   'engineLoadMax': '84',
#   'engineLoadAverage': '39.98',
#   'rpmMax': '3487',
#   'rpmAverage': '1431.29',
#   'gpsSpeedAverage': '21.99',
#   'vssMax': '53.44',
#   'vssAverage': '23.06',
#   'tcuTemperatureMin': '82.40',
#   'tcuTemperatureMax': '109.40',
#   'tcuTemperatureAverage': '104.87',
#   'coolantMin': '158.00',
#   'coolantMax': '188.60',
#   'coolantAverage': '180.20',
#   'packetStartLocal': 1508143346000,
# ...

# %%
type(d)
# Out:
# dict

# %%
d1=d['data']

# %%
del d1['diagnosticTroubleCodeData']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
# ...

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# ...

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url)
# Out:
#     active_lock_reason  assignee assignees author_association  \
# 0                  NaN       NaN        []               NONE
# 1                  NaN       NaN        []               NONE
# 2                  NaN       NaN        []               NONE
# 3                  NaN       NaN        []             MEMBER
# 4                  NaN       NaN        []             MEMBER
# 5                  NaN       NaN        []               NONE
# 6                  NaN       NaN        []               NONE
# 7                  NaN       NaN        []               NONE
# 8                  NaN       NaN        []               NONE
# 9                  NaN       NaN        []             MEMBER
# 10                 NaN       NaN        []               NONE
# 11                 NaN       NaN        []        CONTRIBUTOR
# 12                 NaN       NaN        []               NONE
# 13                 NaN       NaN        []        CONTRIBUTOR
# ...

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1=data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46291',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46291/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46291/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46291/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46291',
#   'id': 1163494319,
#   'node_id': 'I_kwDOAA0YD85FWYOv',
#   'number': 46291,
#   'title': 'ENH: Convert a string column of times (hour:min) to datetime without date',
#   'user': {'login': 'Hadi2525',
#    'id': 23264077,
#    'node_id': 'MDQ6VXNlcjIzMjY0MDc3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23264077?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hadi2525',
#    'html_url': 'https://github.com/Hadi2525',
# ...

# %%
len(data1)
# Out:
# 30

# %%
data1[0]['user']
# Out:
# {'login': 'Hadi2525',
#  'id': 23264077,
#  'node_id': 'MDQ6VXNlcjIzMjY0MDc3',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/23264077?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/Hadi2525',
#  'html_url': 'https://github.com/Hadi2525',
#  'followers_url': 'https://api.github.com/users/Hadi2525/followers',
#  'following_url': 'https://api.github.com/users/Hadi2525/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/Hadi2525/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/Hadi2525/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/Hadi2525/subscriptions',
#  'organizations_url': 'https://api.github.com/users/Hadi2525/orgs',
#  'repos_url': 'https://api.github.com/users/Hadi2525/repos',
#  'events_url': 'https://api.github.com/users/Hadi2525/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/Hadi2525/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
data1[0]['user']['id']
# Out:
# 23264077

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 23264077
# 39504233
# 30965609
# 8519523
# 8078968
# 20634657
# 20634657
# 14360016
# 14360016
# 8078968
# 1182059
# 32567581
# 14360016
# 32567581
# 10820686
# 14360016
# 15113894
# 10901328
# 10820686
# 10820686
# 30958850
# 50843444
# 13092800
# 5902745
# 45140931
# 4567245
# 31669
# 10647082
# 10647082
# 8078968

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46291',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46291/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46291/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46291/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46291',
#   'id': 1163494319,
#   'node_id': 'I_kwDOAA0YD85FWYOv',
#   'number': 46291,
#   'title': 'ENH: Convert a string column of times (hour:min) to datetime without date',
#   'user': {'login': 'Hadi2525',
#    'id': 23264077,
#    'node_id': 'MDQ6VXNlcjIzMjY0MDc3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23264077?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Hadi2525',
#    'html_url': 'https://github.com/Hadi2525',
# ...

# %%
# how can we create table of data1
pd.DataFrame(data1)
# Out:
#    active_lock_reason assignee assignees author_association  \
# 0                None     None        []               NONE
# 1                None     None        []               NONE
# 2                None     None        []               NONE
# 3                None     None        []             MEMBER
# 4                None     None        []             MEMBER
# 5                None     None        []               NONE
# 6                None     None        []               NONE
# 7                None     None        []               NONE
# 8                None     None        []               NONE
# 9                None     None        []             MEMBER
# 10               None     None        []               NONE
# 11               None     None        []        CONTRIBUTOR
# 12               None     None        []               NONE
# 13               None     None        []        CONTRIBUTOR
# 14               None     None        []        CONTRIBUTOR
# ...

# %%
# if we want some specific columns from the the data1, then we can use the following code
data5=pd.DataFrame(data1,columns=['id','url','repository_url','labels_url'])

# %%
data5
# Out:
#             id                                                url  \
# 0   1163494319  https://api.github.com/repos/pandas-dev/pandas...
# 1   1163411318  https://api.github.com/repos/pandas-dev/pandas...
# 2   1163397224  https://api.github.com/repos/pandas-dev/pandas...
# 3   1163387980  https://api.github.com/repos/pandas-dev/pandas...
# 4   1163329444  https://api.github.com/repos/pandas-dev/pandas...
# 5   1163313768  https://api.github.com/repos/pandas-dev/pandas...
# 6   1163286721  https://api.github.com/repos/pandas-dev/pandas...
# 7   1163247362  https://api.github.com/repos/pandas-dev/pandas...
# 8   1163247157  https://api.github.com/repos/pandas-dev/pandas...
# 9   1163243548  https://api.github.com/repos/pandas-dev/pandas...
# 10  1163232999  https://api.github.com/repos/pandas-dev/pandas...
# 11  1163219277  https://api.github.com/repos/pandas-dev/pandas...
# 12  1163209490  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
data5.to_csv('json_res.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes=='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
cn=df.dtypes[df.dtypes=='object'].index

# %%
df[cn]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# 5                                     Moran, Mr. James    male
# 6                              McCarthy, Mr. Timothy J    male
# 7                       Palsson, Master. Gosta Leonard    male
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                     Sandstrom, Miss. Marguerite Rut  female
# 11                            Bonnell, Miss. Elizabeth  female
# 12                      Saundercock, Mr. William Henry    male
# 13                         Andersson, Mr. Anders Johan    male
# ...

# %%
df[cn].describe()
# Out:
#                                 Name   Sex Ticket    Cabin Embarked
# count                            891   891    891      204      889
# unique                           891     2    681      147        3
# top     Hoyt, Mr. Frederick Maxfield  male   1601  B96 B98        S
# freq                               1   577      7        4      644

# %%
# to add a new column to the df
df['ineuron']='channu'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# to delete a specific column
del df['ineuron']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# to extract only name column
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
# to extract first 6 names
df['Name'][0:7]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %%
# to extract alternate names
df['Name'][0:10:2]
# Out:
# 0                              Braund, Mr. Owen Harris
# 2                               Heikkinen, Miss. Laina
# 4                             Allen, Mr. William Henry
# 6                              McCarthy, Mr. Timothy J
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Name: Name, dtype: object

# %%
# finding null values
df[df['Age'].isnull()==True].index
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
# to find total null values
len(df[df['Age'].isnull()==True].index)
# Out:
# 177

# %%
ind=df[df['Age'].isnull()==True].index

# %%
df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
# to findout the maximum fare
max(df['Fare'])
# Out:
# 512.3292

# %%
# to findout the maximum fare paid by the passenger
df[df['Fare']==max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
1 . Find out how many male and female passenger was onboarded .
2. how many survived we have .
3. how many casuality we have 
4 . what is name of a person who is the eldest one . 
5 . how many passenger do we have in first , second and third class 
6. how many person we have whose name starts with "s"
7. try to create a new column which is a summation  of "SibSp" and "parch"
8 . how many person do we have below age of 25 .
9 . how many person died whose age was less then 40 
10 . from a  cabin column seperate text and numeric value .

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#1 . Find out how many male and female passenger was onboarded


len(df[df['Sex']=='male'])
# Out:
# 577

# %%
len(df[df['Sex']=='female'])
# Out:
# 314

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#2. how many survived we have .


len(df[df['Survived']==1])
# Out:
# 342

# %%
#3. how many casuality we have 


len(df[df["Survived"]==0])
# Out:
# 549

# %%
df['Survived'].value_counts()
# this will the count of both survived and casuality
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#4 . what is name of a person who is the eldest one .


max(df['Age'])
# Out:
# 80.0

# %%
df[df['Age']==max(df['Age'])]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
#5 . how many passenger do we have in first , second and third class 


len(df[df['Pclass']==1])
#This is the no.of passenger in first class
# Out:
# 216

# %%
len(df[df['Pclass']==2])
#This is the no.of passenger in second class
# Out:
# 184

# %%
len(df[df['Pclass']==3])
#This is the no.of passenger in third class
# Out:
# 491

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#6. how many person we have whose name starts with "s"

len(df[df['Name'].str.startswith("S")]['Name'])
# Out:
# 86

# %%
#7. try to create a new column which is a summation  of "SibSp" and "parch"

df['new']=df['SibSp']+df['Parch']
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new
# 0      0  A/5 21171   7.2500   NaN        S    1
# 1      0   PC 17599  71.2833   C85        C    1

# %%
#8 . how many person do we have below age of 25 .

len(df[df['Age']<25])
# Out:
# 278

# %%
#9 . how many person died whose age was less then 40 

len(df[(df['Survived'] == 0 ) & (df["Age"] < 40)])
# Out:
# 322

# %%
#10 . from a  cabin column seperate text and numeric value . 

df['cabin_Letter'] = df['Cabin'].str.extract('([A-Za-z]+)')
df['cabin_Number'] = df['Cabin'].str.replace('([A-Za-z]+)', '')
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new cabin_Letter cabin_Number
# 0      0  A/5 21171   7.2500   NaN        S    1          NaN          NaN
# 1      0   PC 17599  71.2833   C85        C    1            C           85

# %%
import pandas as pd
df8=pd.read_csv(r"C:\Users\Agstat Lab\Desktop\ineuron1\bank.csv")

# %%
df9=pd.read_csv(r"C:\Users\Agstat Lab\Desktop\ineuron1\bank.csv",sep=';')
df9.head(2)
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   30  unemployed  married    primary      no     1787      no   no
# 1   33    services  married  secondary      no     4789     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no

# %%
1 . how many campaign available in this dataset . 
2 . how many users do we have with housing and personal loan . 
3. how many person do we have whose age is 60+ . 
4 . in which month we have trageted most of the customer . 
5 . which mode of call is giving you more result
6 . how many enterpeures do we have in this list  
7 . how many customers do we have with negative balance 
8. prepare a group of data based on education level .

# %%
df9.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
len(df9[df9['campaign']==1])
# Out:
# 1734

# %%
# 2 . how many users do we have with housing and personal loan .
len(df9[(df9['housing']=='yes')&(df9['loan']=='yes')])
# Out:
# 406

# %%
# 3. how many person do we have whose age is 60+ . 
len(df9[df9['age']>60])
# Out:
# 127

# %%
# 4 . in which month we have trageted most of the customer .
df9["month"].value_counts().index[0]
# Out:
# 'may'

# %%
df9['month'].value_counts()
# Out:
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# apr     293
# feb     222
# jan     148
# oct      80
# sep      52
# mar      49
# dec      20
# Name: month, dtype: int64

# %%
# 5 . which mode of call is giving you more result
df9['contact'].value_counts()
# Out:
# cellular     2896
# unknown      1324
# telephone     301
# Name: contact, dtype: int64

# %%
df_groupby=df9.groupby(['contact','y']).count()

# %%
df_groupby.loc['cellular','yes'][0]
# Out:
# 416

# %%
df_groupby.loc['telephone','yes'][0]
# Out:
# 44

# %%
df_groupby.loc['unknown','yes'][0]
# Out:
# 61

# %%
max(df_groupby.loc['cellular','yes'][0],df_groupby.loc['telephone','yes'][0],df_groupby.loc['unknown','yes'][0])
# Out:
# 416

# %%
# 6 . how many enterpeures do we have in this list
len(df9[df9['job']=='entrepreneur'])
# Out:
# 168

# %%
# 7 . how many customers do we have with negative balance 
len(df9[df9['balance']<0])
# Out:
# 366

# %%
# 8. prepare a group of data based on education level .
l = []
for i in df9['education'].unique() : 
    l.append(df9[df9["education"]  == i])

# %%
len(l)
# Out:
# 4

# %%
l[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# 46     55    blue-collar   married   primary      no      145      no   no
# 47     26    blue-collar   married   primary      no        0     yes   no
# 48     32   entrepreneur    single   primary     yes     -849     yes  yes
# 50     45    blue-collar  divorced   primary      no      844      no   no
# 60     41    blue-collar   married   primary      no     -516      no  yes
# 78     50    blue-collar  divorced   primary      no      388      no   no
# ...

# %%
l[1]
# Out:
#       age            job   marital  education default  balance housing loan  \
# 1      33       services   married  secondary      no     4789     yes  yes
# 4      59    blue-collar   married  secondary      no        0     yes   no
# 7      39     technician   married  secondary      no      147     yes   no
# 10     39       services   married  secondary      no     9374     yes   no
# 11     43         admin.   married  secondary      no      264     yes   no
# 13     20        student    single  secondary      no      502      no   no
# 14     31    blue-collar   married  secondary      no      360     yes  yes
# 16     56     technician   married  secondary      no     4073      no   no
# 19     31       services   married  secondary      no      132      no   no
# 22     44       services    single  secondary      no      106      no   no
# 23     44   entrepreneur   married  secondary      no       93      no   no
# ...

# %%
l[2]
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# 12     36     technician   married  tertiary      no     1109      no   no
# 15     40     management   married  tertiary      no      194      no  yes
# 17     37         admin.    single  tertiary      no     2317     yes   no
# 21     42     management  divorced  tertiary      no       16      no   no
# 24     26      housemaid   married  tertiary      no      543      no   no
# 25     41     management   married  tertiary      no     5883      no   no
# ...

# %%
l[3]
# Out:
#       age            job   marital education default  balance housing loan  \
# 20     38     management  divorced   unknown      no        0     yes   no
# 27     67        retired   married   unknown      no      696      no   no
# 49     61         admin.   married   unknown      no     4629     yes   no
# 132    43    blue-collar   married   unknown     yes     -715     yes   no
# 133    48         admin.   married   unknown      no        0     yes   no
# 139    60     management   married   unknown      no     6313      no   no
# 142    56       services  divorced   unknown      no     1877     yes   no
# 149    37     technician    single   unknown      no      391     yes   no
# 150    41   entrepreneur   married   unknown      no       89     yes   no
# 178    37        unknown   married   unknown      no     1699      no   no
# 237    57     technician   married   unknown      no      206     yes   no
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
 
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna()
# df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
# here axis 0 represent row and 1 represent column
# inplace = true, it will update the df.
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.isnull().sum()
# we found 3 columns having the null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(axis=1,thresh=800)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.dropna(axis=1,how='all')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1,how='any')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.fillna(value='crv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# replace NAN with the average of age
df.fillna(value=df['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.groupby('Survived').describe()
# Out:
#          PassengerId                                                     \
#                count        mean         std  min     25%    50%    75%
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.00  455.0  675.0
# 1              342.0  444.368421  252.358840  2.0  250.75  439.5  651.5
#
#                 Pclass            ... Parch        Fare                        \
#             max  count      mean  ...   75%  max  count       mean        std
# Survived                          ...
# 0         891.0  549.0  2.531876  ...   0.0  6.0  549.0  22.117887  31.388207
# 1         890.0  342.0  1.950292  ...   1.0  5.0  342.0  48.395408  66.596998
#
#
#           min      25%   50%   75%       max
# Survived
# 0         0.0   7.8542  10.5  26.0  263.0000
# 1         0.0  12.4750  26.0  57.0  512.3292
#
# [2 rows x 48 columns]

# %%
df.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min     25%    50%    75%    max
# Survived
# 0         549.0  447.016393  260.640469  1.0  211.00  455.0  675.0  891.0
# 1         342.0  444.368421  252.358840  2.0  250.75  439.5  651.5  890.0

# %%
df.groupby('Survived').describe()['PassengerId'].transpose()
# Out:
# Survived           0           1
# count     549.000000  342.000000
# mean      447.016393  444.368421
# std       260.640469  252.358840
# min         1.000000    2.000000
# 25%       211.000000  250.750000
# 50%       455.000000  439.500000
# 75%       675.000000  651.500000
# max       891.000000  890.000000

# %%
df=pd.read_csv(r"C:\Users\harishnayak\Desktop\ineuron1\bank.csv",sep=';')

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
l=[]
for i in df['education'].unique():
    l.append(df[df['education']==i])

# %%
df1=l[0]

# %%
len(df1)
# Out:
# 678

# %%
df2=l[1]

# %%
len(df2)
# Out:
# 2306

# %%
df3=l[2]

# %%
len(df3)
# Out:
# 1350

# %%
df1.head(2)
# Out:
#    age         job  marital education default  balance housing loan   contact  \
# 0   30  unemployed  married   primary      no     1787      no   no  cellular
# 9   43    services  married   primary      no      -88     yes  yes  cellular
#
#    day month  duration  campaign  pdays  previous poutcome   y
# 0   19   oct        79         1     -1         0  unknown  no
# 9   17   apr       313         1    147         2  failure  no

# %%
'channa'+'basava'
# Out:
# 'channabasava'

# %%
pd.concat([df1,df2])
# concatinating two dataframes
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 9      43     services   married    primary      no      -88     yes  yes
# 18     25  blue-collar    single    primary      no     -221     yes   no
# 26     55  blue-collar   married    primary      no      627     yes   no
# 36     78      retired  divorced    primary      no      229      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar   married  secondary      no     1205     yes   no
# 4515   32     services    single  secondary      no      473     yes   no
# 4516   33     services   married  secondary      no     -333     yes   no
# 4518   57   technician   married  secondary      no      295      no   no
# 4519   28  blue-collar   married  secondary      no     1137      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
# concatenate column wise
pd.concat([df1,df2],axis=1)
# Out:
#        age         job  marital education default  balance housing loan  \
# 0     30.0  unemployed  married   primary      no   1787.0      no   no
# 1      NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
# 4      NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
# 7      NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
# 9     43.0    services  married   primary      no    -88.0     yes  yes
# ...    ...         ...      ...       ...     ...      ...     ...  ...
# 4514   NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
# 4515   NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
# 4516   NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
# 4518   NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
# 4519   NaN         NaN      NaN       NaN     NaN      NaN     NaN  NaN
#
#        contact   day  ... loan   contact   day  month  duration campaign  \
# ...

# %%
df1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df4=df2.head()[['age','job','marital']]

# %%
df4
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df2[['age','job','marital']]
# Out:
#       age          job  marital
# 1      33     services  married
# 4      59  blue-collar  married
# 7      39   technician  married
# 10     39     services  married
# 11     43       admin.  married
# ...   ...          ...      ...
# 4514   38  blue-collar  married
# 4515   32     services   single
# 4516   33     services  married
# 4518   57   technician  married
# 4519   28  blue-collar  married
#
# [2306 rows x 3 columns]

# %%
df5=df.head()[['age','job','marital']]

# %%
df5
# Out:
#    age          job  marital
# 0   30   unemployed  married
# 1   33     services  married
# 2   35   management   single
# 3   30   management  married
# 4   59  blue-collar  married

# %%
df6=pd.concat([df4,df5],axis=1)

# %%
df6
# Out:
#      age          job  marital   age          job  marital
# 0    NaN          NaN      NaN  30.0   unemployed  married
# 1   33.0     services  married  33.0     services  married
# 2    NaN          NaN      NaN  35.0   management   single
# 3    NaN          NaN      NaN  30.0   management  married
# 4   59.0  blue-collar  married  59.0  blue-collar  married
# 7   39.0   technician  married   NaN          NaN      NaN
# 10  39.0     services  married   NaN          NaN      NaN
# 11  43.0       admin.  married   NaN          NaN      NaN

# %%
df6['age']
# Out:
#      age   age
# 0    NaN  30.0
# 1   33.0  33.0
# 2    NaN  35.0
# 3    NaN  30.0
# 4   59.0  59.0
# 7   39.0   NaN
# 10  39.0   NaN
# 11  43.0   NaN

# %%
df6.iloc[: ,3]
# Out:
# 0     30.0
# 1     33.0
# 2     35.0
# 3     30.0
# 4     59.0
# 7      NaN
# 10     NaN
# 11     NaN
# Name: age, dtype: float64

# %%
df6.iloc[[4,5],[3,4]]
# Out:
#     age          job
# 4  59.0  blue-collar
# 7   NaN          NaN

# %%
df4
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df4.loc[[4,7] , ['job','marital']]
# using loc
# Out:
#            job  marital
# 4  blue-collar  married
# 7   technician  married

# %%
df4.iloc[[1,2],[1,2]]
# using iloc
# Out:
#            job  marital
# 4  blue-collar  married
# 7   technician  married

# %%
df4.iloc[[1,2],[0,2]]
# Out:
#    age  marital
# 4   59  married
# 7   39  married

# %%
df4
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df5
# Out:
#    age          job  marital
# 0   30   unemployed  married
# 1   33     services  married
# 2   35   management   single
# 3   30   management  married
# 4   59  blue-collar  married

# %%
pd.merge(df4,df5)
# Out:
#    age          job  marital
# 0   33     services  married
# 1   59  blue-collar  married

# %%
pd.merge(df4,df5,on='age')
# it will give the intersection(commonn) result
# Out:
#    age        job_x marital_x        job_y marital_y
# 0   33     services   married     services   married
# 1   59  blue-collar   married  blue-collar   married

# %%
pd.merge(df4,df5,on='age',how='left')
# it will give the lefft join function
# Out:
#    age        job_x marital_x        job_y marital_y
# 0   33     services   married     services   married
# 1   59  blue-collar   married  blue-collar   married
# 2   39   technician   married          NaN       NaN
# 3   39     services   married          NaN       NaN
# 4   43       admin.   married          NaN       NaN

# %%
pd.merge(df4,df5,on='age',how='right')
# it will give the right join function
# Out:
#    age        job_x marital_x        job_y marital_y
# 0   30          NaN       NaN   unemployed   married
# 1   33     services   married     services   married
# 2   35          NaN       NaN   management    single
# 3   30          NaN       NaN   management   married
# 4   59  blue-collar   married  blue-collar   married

# %%
pd.merge(df4,df5,on='age',how='outer')
# it will give the union operation
# Out:
#    age        job_x marital_x        job_y marital_y
# 0   33     services   married     services   married
# 1   59  blue-collar   married  blue-collar   married
# 2   39   technician   married          NaN       NaN
# 3   39     services   married          NaN       NaN
# 4   43       admin.   married          NaN       NaN
# 5   30          NaN       NaN   unemployed   married
# 6   30          NaN       NaN   management   married
# 7   35          NaN       NaN   management    single

# %%
df4=df4.set_index('age')

# %%
df5=df5.set_index('age')

# %%
df4.rename(columns={'job' : 'job1' , "marital" : 'marital1'},inplace=True)

# %%
df4
# Out:
#             job1 marital1
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
df4.join(df5 ,how = 'inner')
# Out:
#             job1 marital1          job  marital
# age
# 33      services  married     services  married
# 59   blue-collar  married  blue-collar  married

# %%
pd.merge(df4,df5,left_on='job1' , right_on='job')
# Out:
#           job1 marital1          job  marital
# 0     services  married     services  married
# 1     services  married     services  married
# 2  blue-collar  married  blue-collar  married

# %%
import pandas as pd

# %%
pd.DataFrame({'col1':[1,2,3,4,5],
             'col2':[45,56,67,34,34],
             'col3':"sudh kumar krish ineuron crv"            
             })
# Out:
#    col1  col2                          col3
# 0     1    45  sudh kumar krish ineuron crv
# 1     2    56  sudh kumar krish ineuron crv
# 2     3    67  sudh kumar krish ineuron crv
# 3     4    34  sudh kumar krish ineuron crv
# 4     5    34  sudh kumar krish ineuron crv

# %%
"sudh kumar krish ineuron crv" .split()
# Out:
# ['sudh', 'kumar', 'krish', 'ineuron', 'crv']

# %%
df=pd.DataFrame({'col1':[1,2,3,4,5],
             'col2':[45,56,67,34,34],
             'col3':"sudh kumar krish ineuron crv".split()           
             })

# %%
df
# Out:
#    col1  col2     col3
# 0     1    45     sudh
# 1     2    56    kumar
# 2     3    67    krish
# 3     4    34  ineuron
# 4     5    34      crv

# %%
# create col4, which is square of the col1
df['col4']=df['col1']**2

# %%
df
# Out:
#    col1  col2     col3  col4
# 0     1    45     sudh     1
# 1     2    56    kumar     4
# 2     3    67    krish     9
# 3     4    34  ineuron    16
# 4     5    34      crv    25

# %%
# create col5, which can hold first letter of col3
df['col5']=df['col3'].str[0]

# %%
df
# Out:
#    col1  col2     col3  col4 col5
# 0     1    45     sudh     1    s
# 1     2    56    kumar     4    k
# 2     3    67    krish     9    k
# 3     4    34  ineuron    16    i
# 4     5    34      crv    25    c

# %%
# create col6, which can hold complex(if col5 having letter s then keep it o.w keep as z)
def test(a):
    return a**2

# %%
df['col4_4']=df['col1'].apply(test)

# %%
df
# Out:
#    col1  col2     col3  col4 col5  col4_4
# 0     1    45     sudh     1    s       1
# 1     2    56    kumar     4    k       4
# 2     3    67    krish     9    k       9
# 3     4    34  ineuron    16    i      16
# 4     5    34      crv    25    c      25

# %%
def test1(a):
    if a=='s':
        return 's'
    else:
        return 'z'

# %%
df['col6']=df['col5'].apply(test1)

# %%
df
# Out:
#    col1  col2     col3  col4 col5  col4_4 col6
# 0     1    45     sudh     1    s       1    s
# 1     2    56    kumar     4    k       4    z
# 2     3    67    krish     9    k       9    z
# 3     4    34  ineuron    16    i      16    z
# 4     5    34      crv    25    c      25    z

# %%
df['col6_6']=df['col5'].apply(lambda a:'s' if a=='s' else 'z')

# %%
df
# Out:
#    col1  col2     col3  col4 col5  col4_4 col6 col6_6
# 0     1    45     sudh     1    s       1    s      s
# 1     2    56    kumar     4    k       4    z      z
# 2     3    67    krish     9    k       9    z      z
# 3     4    34  ineuron    16    i      16    z      z
# 4     5    34      crv    25    c      25    z      z

# %%
# create a col7, which is the length of col3
df['col7']=df['col3'].apply(len)

# %%
df
# Out:
#    col1  col2     col3  col4 col5  col4_4 col6 col6_6  col7
# 0     1    45     sudh     1    s       1    s      s     4
# 1     2    56    kumar     4    k       4    z      z     5
# 2     3    67    krish     9    k       9    z      z     5
# 3     4    34  ineuron    16    i      16    z      z     7
# 4     5    34      crv    25    c      25    z      z     3

# %%
import math

# %%
# create col8, which is a logerithmic of col2
df['col8']=df['col2'].apply(math.log)

# %%
df
# Out:
#    col1  col2     col3  col4 col5  col4_4 col6 col6_6  col7      col8
# 0     1    45     sudh     1    s       1    s      s     4  3.806662
# 1     2    56    kumar     4    k       4    z      z     5  4.025352
# 2     3    67    krish     9    k       9    z      z     5  4.204693
# 3     4    34  ineuron    16    i      16    z      z     7  3.526361
# 4     5    34      crv    25    c      25    z      z     3  3.526361

# %%
math.log(45)
# Out:
# 3.8066624897703196

# %%
def test3(a):
    return math.log(a)

# %%
df['col8_8']=df['col2'].apply(test3)

# %%
df
# Out:
#    col1  col2     col3  col4 col5  col4_4 col6 col6_6  col7      col8  \
# 0     1    45     sudh     1    s       1    s      s     4  3.806662
# 1     2    56    kumar     4    k       4    z      z     5  4.025352
# 2     3    67    krish     9    k       9    z      z     5  4.204693
# 3     4    34  ineuron    16    i      16    z      z     7  3.526361
# 4     5    34      crv    25    c      25    z      z     3  3.526361
#
#      col8_8
# 0  3.806662
# 1  4.025352
# 2  4.204693
# 3  3.526361
# 4  3.526361
